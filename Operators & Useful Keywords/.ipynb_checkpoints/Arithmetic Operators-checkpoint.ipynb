# %% [markdown]
# # Arithmetic Operators
#
# - These operators perform basic arithmetic operations on numbers.
#
# We have the following arithmetic operators:
#
# ![image.png](attachment:image.png)
#
# (Reference: [this GFG article](https://www.geeksforgeeks.org/python-operators/))

# %%
a = 10
b = 20

# %%
# addition
a + b
# Out:
# 30

# %%
# subtraction
a - b
# Out:
# -10

# %%
# multiplication
a * b
# Out:
# 200

# %%
# floating point division
a / b
# Out:
# 0.5

# %%
a = 30

# %%
# integer division
a // b
# Out:
# 1

# %%
# remainder
a % b
# Out:
# 10

# %%
# exponentiation
a ** b
# Out:
# 348678440100000000000000000000
